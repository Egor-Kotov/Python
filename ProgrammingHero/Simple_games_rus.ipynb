# %%
# Угадай число от 1 до 10
from random import randint

points = 0

while True:
    rand = randint(1, 10)
    number = input('Введите число от 1 до 10\nИли q для выхода из игры ')
    if number == 'q': 
        points = 0
        break
    elif rand == int(number):
        points +=10
        print(f"\nКрасавчик!!!\nТвой счет: {points}\nЕщё разок???")
    else:
        print(f'\nО, нет!! Это было {rand}\nЕщё разок?')
# Out:
# Введите число от 1 до 10
# Или q для выхода из игры 5
#
# О, нет!! Это было 10
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 4
#
# О, нет!! Это было 10
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 7
#
# О, нет!! Это было 9
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 5
#
# О, нет!! Это было 6
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 2
#
# О, нет!! Это было 7
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 3
#
# О, нет!! Это было 9
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 8
#
# О, нет!! Это было 3
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 2
#
# О, нет!! Это было 1
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 9
#
# Красавчик!!!
# Твой счет: 10
# Ещё разок???
# Введите число от 1 до 10
# Или q для выхода из игры 10
#
# О, нет!! Это было 7
# Ещё разок?
# Введите число от 1 до 10
# Или q для выхода из игры 4
#
# Красавчик!!!
# Твой счет: 20
# Ещё разок???
# Введите число от 1 до 10
# Или q для выхода из игры q

# %%
# Камень-ножницы-бумага
from random import randint
  
def igra():
    evil = 0
    good = 0
    def chiu(x, y):
      if x > y:
        return "в твою пользу, добивай уже!))"
      elif y > x:
        return "редиска побеждает((("
      else:
        return "ничья... поднажми!"
    
    print("\nПогнали брат, до трех побед!\n")
    while True:
      if  evil == 3:
        print("\n\n\nУнижен и растоптан... Зачем ты вообще начал, если ни на что неспособен...")
        good =  evil = 0
        break
      elif good == 3:
        print("\n\n\nКрасавчик! Если бы знал, что ты на столько хорош, выбрал бы тебе соперника помощнее. Следующего сюда несите!")
        good = evil = 0
        break
      vibor = input('\nКамень, ножницы, бумага, цу-е-фа! ')
      vibor = vibor.lower()
      if vibor != 'камень' and vibor != 'бумага' and vibor != 'ножницы':
        print("Опечатка, напиши нормально!")
        continue 
      protiv = randint(1, 3)
      if protiv == 1:
        protiv = 'камень'
      elif protiv == 2:
        protiv = 'ножницы'
      else:
        protiv = 'бумага'
  
      if vibor == 'камень' and protiv == 'ножницы' or vibor == 'ножницы' and protiv == 'бумага' or vibor == 'бумага' and protiv == 'камень':
        good += 1
        print(f"Ты разматал, у противника - {protiv}.")
        print(f"Счет {good} - {evil} {chiu(good, evil)}")
      elif vibor == protiv:
        print(f"Пффф... {vibor} - {protiv}\nЕщё разок!")
      else:
        evil += 1
        print(f"Это ловушка!!! У противника - {protiv}.")
        print(f"Счет {good} - {evil} {chiu(good, evil)}")
        
raz = 0
def razok():
    if raz == 0:
        return ''
    else:
        return 'еще разок '             
while True:
    a = input(f'\nХочешь {razok()}сыграть в камень-ножницы-бумага???\nВведи да или нет: ')
    a = a.lower()
    if a != 'да' and a != 'нет':
        print('\nПиши пожалуйста, по-русски...')
        continue
    if a == 'да':
        raz += 1
        igra()
    else:
         raz = 0
         print('Трусишь небось... Ладно мб в другой раз')
         break
# Out:
# Хочешь сыграть в камень-ножницы-бумага???
# Введи да или нет: да
#
# Погнали брат, до трех побед!
#
#
# Камень, ножницы, бумага, цу-е-фа! ножницы
# Это ловушка!!! У противника - камень.
# Счет 0 - 1 редиска побеждает(((
#
# Камень, ножницы, бумага, цу-е-фа! ножницы
# Пффф... ножницы - ножницы
# Ещё разок!
#
# Камень, ножницы, бумага, цу-е-фа! камень
# Это ловушка!!! У противника - бумага.
# Счет 0 - 2 редиска побеждает(((
#
# Камень, ножницы, бумага, цу-е-фа! ножницы
# Это ловушка!!! У противника - камень.
# Счет 0 - 3 редиска побеждает(((
#
#
#
# Унижен и растоптан... Зачем ты вообще начал, если ни на что неспособен...
#
# Хочешь еще разок сыграть в камень-ножницы-бумага???
# Введи да или нет: нет
# Трусишь небось... Ладно мб в другой раз

# %%
# Быки и коровы
from random import randint
while True:
    try:
        n = int(input("\nСколько цифр в числе?\n(2, 3 или 4) "))
    except:
        print("\nВведите цифру")
        continue
    if n == 3 or n == 2 or n == 4:
        break
    else:
        print("\nВыберите из доступных вариантов")

def unuqint_randlist(x):
    a = []
    a.append(randint(1, 9))
    while len(a) < x:
        i = randint(0, 9)
        if i not in a:
            a.append(i)
    return a

n = unuqint_randlist(n)
print(n)

def slova(x):
    if x == 2:
        return "от 10 до 99"
    elif x == 3:
        return "от 100 до 999"
    else:
        return "от 1000 до 9999"

def u_l(x):
    y = x[:]
    z = y.pop()
    if z in y:
        return True

while True:
    try:
        popitka = int(input("\nЗа сколько попыток управишься? "))
        break
    except ValueError:
        print("Вы ввели число? Попытайтесь еще раз.")
        continue
    

while True:
    if popitka == 0:
        print("\nУ вас закончились попытки((((\n\nGame Over")
        break
    try:
        dogadka = int(input("\nКакое число, как думаешь? "))
    except ValueError:
        print("Вы ввели число? Попытайтесь еще раз.")
        continue
    dogadka = [int(i) for i in str(dogadka)]
    if len(n) != len(dogadka):
        print(f"Мы загадали число {slova(len(n))}")
        continue
    elif u_l(dogadka):
        print("Число должно быть с неповторяющимися цифрами")
        continue
    elif dogadka == n:
        print('Вы угадали, умница!')
        break
    cow = 0
    bull = 0
    for i in range(len(n)):
        if dogadka[i] == n[i]:
            bull += 1
        elif dogadka[i] in n:
            cow += 1
    popitka -= 1
    print(f"{bull} быков и {cow} коров, осталось {popitka} попыток")
# Out:
# Сколько цифр в числе?
# (2, 3 или 4) 12321321
#
# Выберите из доступных вариантов
#
# Сколько цифр в числе?
# (2, 3 или 4) 4
# [2, 9, 1, 0]
#
# За сколько попыток управишься? 12
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 11 попыток
#
# Какое число, как думаешь? 1111
# Число должно быть с неповторяющимися цифрами
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 10 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 9 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 8 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 7 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 6 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 5 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 4 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 3 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 2 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 1 попыток
#
# Какое число, как думаешь? 1234
# 0 быков и 2 коров, осталось 0 попыток
#
# У вас закончились попытки((((
#
# Game Over
